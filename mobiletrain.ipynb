# %%
import pandas as pd 
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tp = pd.read_csv('E:/mobile_train.csv')
tp.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
tp.shape
# Out:
# (2000, 21)

# %%
tp.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
tp['battery_power'].max()
# Out:
# 1998

# %%
tp['int_memory'].min()
# Out:
# 2

# %%
tp.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
tp_corr = tp[['battery_power','clock_speed','dual_sim','four_g','int_memory','mobile_wt','ram','three_g','price_range']].corr()
tp_corr
# Out:
#                battery_power  clock_speed  dual_sim    four_g  int_memory  \
# battery_power       1.000000     0.011482 -0.041847  0.015665   -0.004004
# clock_speed         0.011482     1.000000 -0.001315 -0.043073    0.006545
# dual_sim           -0.041847    -0.001315  1.000000  0.003187   -0.015679
# four_g              0.015665    -0.043073  0.003187  1.000000    0.008690
# int_memory         -0.004004     0.006545 -0.015679  0.008690    1.000000
# mobile_wt           0.001844     0.012350 -0.008979 -0.016537   -0.034214
# ram                -0.000653     0.003443  0.041072  0.007313    0.032813
# three_g             0.011522    -0.046433 -0.014008  0.584246   -0.009366
# price_range         0.200723    -0.006606  0.017444  0.014772    0.044435
#
#                mobile_wt       ram   three_g  price_range
# battery_power   0.001844 -0.000653  0.011522     0.200723
# clock_speed     0.012350  0.003443 -0.046433    -0.006606
# ...

# %%
sns.heatmap(tp_corr,annot=True,vmin=-1,vmax=1,cmap='Purples')
# Out:
# <AxesSubplot:>

# %%
print(tp['battery_power'].unique())
# Out:
# [ 842 1021  563 ... 1139 1467  858]

# %%
print(tp['ram'].unique())
# Out:
# [2549 2631 2603 ... 2032 3057 3919]

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=tp['price_range'],y=tp['ram'])
plt.title('How price range changes whith ram' ,fontsize=25)
plt.xlabel('price_range',fontsize=20)
plt.ylabel('ram',fontsize=20)
# Out:
# Text(0, 0.5, 'ram')

# %%
plt.figure(figsize=(15,8))
plt.plot(tp['price_range'],tp['ram'])
plt.title('How price range changes whith ram',fontsize=15)
plt.xlabel('price_range',fontsize=15)
plt.ylabel('ram',fontsize=15)
# Out:
# Text(0, 0.5, 'ram')

# %%
corr =tp.corr()
fig=plt.figure(figsize=(15,12))
r=sns.heatmap(corr,cmap='Purples')
r.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
sns.boxplot (tp['price_range'],tp['talk_time'])
# Out:
# C:\Users\shree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='talk_time'>

# %%
labels =["3G - supported",'Not supported']
values= tp['three_g'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
colors =['gold','lightskyblue']
ax1.pie(values,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %%
labels=["4-supported",'Not suppoerted']
values=tp['four_g'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
colors =['gold','lightskyblue']
ax1.pie(values,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.svm import SVC

# %%
x= tp.drop('price_range',axis=1)
scaler = StandardScaler()
y=tp['price_range'] #0 1 2 3 classification clusters

scaler.fit(x)
x_transformed =scaler.transform(x)

x_train,x_test,y_train,y_test =train_test_split(x_transformed,y,test_size=0.3)

# %%
#SVM support vector machine 
model = SVC()
model.fit(x_train,y_train)
y_train_pred = model.predict(x_train)
y_test_pred =model.predict(x_test)

print("Train Set Accuracy:" +str(accuracy_score(y_train_pred,y_train)*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test_pred,y_test)*100))
print("nConfusion Matrix: \n%s"%confusion_matrix(y_test_pred,y_test))
print("nClssificationReport :\n%s"%classification_report(y_test_pred,y_test))
# Out:
# Train Set Accuracy:98.42857142857143
# Test Set Accuracy:88.0
# nConfusion Matrix:
# [[149  11   0   0]
#  [ 12 135  17   0]
#  [  0  16 116  12]
#  [  0   0   4 128]]
# nClssificationReport :
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       160
#            1       0.83      0.82      0.83       164
#            2       0.85      0.81      0.83       144
#            3       0.91      0.97      0.94       132
#
#     accuracy                           0.88       600
#    macro avg       0.88      0.88      0.88       600
# weighted avg       0.88      0.88      0.88       600
